# %%
import pandas as pd
from FB_features.new_meta_country import NewMetaCountryMapping

# %%
handler = NewMetaCountryMapping()

# %% [markdown]
# ### Check if Meta supports Zipcodes for the Country

# %%
handler.check_compatibility_zipcode(
    country_code="SA",
    popular_zipcode="11372"
)
# Out:
# No data was found for:
# -> zipcode: 11372
# -> country: SA
#
# Either Meta doesn't support zipcodes for this country or try a different popular zipcode

# %% [markdown]
# ### Check if Meta supports Cities for the Country

# %%
handler.check_compatibility_city(
    country_code="SA",
    popular_city="Dhahran"
)
# Out:
# Results for city: Dhahran
#
#        key                                         name          type country_code  country_name            region  region_id  supports_region  supports_city geo_hierarchy_level geo_hierarchy_name
# 0  2115958                       Dhahran, Ash Sharqiyah          city           SA  Saudi Arabia  Eastern Province       3202             True           True                 NaN                NaN
# 1  2893100                                    Al Jameah  neighborhood           SA  Saudi Arabia  Eastern Province       3202             True           True        NEIGHBORHOOD       NEIGHBORHOOD
# 2  2893123                                    Al Taraji  neighborhood           SA  Saudi Arabia  Eastern Province       3202             True           True        NEIGHBORHOOD       NEIGHBORHOOD
# 3  2893114  King Fahd University of Pet and Min - KFUPM  neighborhood           SA  Saudi Arabia  Eastern Province       3202             True           True        NEIGHBORHOOD       NEIGHBORHOOD
# 4  2115959                               Dhahran, Jizan          city           SA  Saudi Arabia      'Asir Region       4201             True           True                 NaN                NaN

# %% [markdown]
# ### Setup the Scraper
#
# ### If Meta supports ZIP-level data:
# 1. **Download the XANDR Mapping File for ZIP Codes**
#    Access the mapping file from the following AWS S3 bucket:
#    [XANDR Postal Code Mapping File](https://eu-west-1.console.aws.amazon.com/s3/buckets/qrtz-bucket?region=eu-west-1&bucketType=general&prefix=xandr/api/postal_code/&showversions=false)
#
# 2. **Set Variables:**
#    - `geo_level = 'zip'`
#    - `xandr_mapping = [file path to XANDR mapping file downloaded above]`
#
# ---
#
# ### If Meta supports City-level data instead of ZIP-level data:
# 1. **Download the XANDR Mapping File for Cities**
#    Access the mapping file from the following AWS S3 bucket:
#    [XANDR City Mapping File](https://eu-west-1.console.aws.amazon.com/s3/buckets/qrtz-bucket?region=eu-west-1&bucketType=general&prefix=xandr/api/city/&showversions=false)
#
# 2. **Set Variables:**
#    - `geo_level = 'city'`
#    - `xandr_mapping = [file path to XANDR mapping file downloaded above]`

# %%
threads       = 5 #Number of threads to allocate on your CPU (allows your the script to finish faster)
xandr_mapping = pd.read_parquet("../All_postcodes/SA_cities.parquet")
geo_level     = "city"     #'zip' or 'city'
geo_column    = "name" #Name of column in xandr_mapping which includes the names of the geo_level selected e.g. cities / zipcodes
country_code  = "SA"

# %%
handler.start_scrape(
    threads = threads,
    country_code = country_code,
    geo_level    = geo_level,
    xandr_mapping = xandr_mapping,
    geo_column = geo_column
)
# Out:
# {'data': []}
# Completed 5 / 648
# {'data': []}
# Completed 6 / 648
# {'data': [{'key': '2115958', 'name': 'Dhahran, Ash Sharqiyah', 'type': 'city', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True}, {'key': '2893100', 'name': 'Al Jameah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2893123', 'name': 'Al Taraji', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2893114', 'name': 'King Fahd University of Pet and Min - KFUPM', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2115959', 'name': 'Dhahran, Jizan', 'type': 'city', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': "'Asir Region", 'region_id': 4201, 'supports_region': True, 'supports_city': True}, {'key': '2893104', 'name': 'Al Doha Al Shamaliah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2893102', 'name': 'Al Dawhah Al Janubiyah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2893116', 'name': 'Al Dana Al Shamaliah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2893089', 'name': 'Al Dana Al Jenobiah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'OAZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Dhahran&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=OAZDZD'}}
# Completed 7 / 648
# {'data': []}
# Completed 8 / 648
# {'data': []}
# Completed 9 / 648
# {'data': []}
# Completed 10 / 648
# {'data': []}
# Completed 11 / 648
# {'data': []}
# Completed 12 / 648
# {'data': []}
# Completed 13 / 648
# {'data': [{'key': '2117479', 'name': 'Riyadh', 'type': 'city', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True}, {'key': '2936173', 'name': 'Gharnatah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2936287', 'name': 'King Fahd', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2936303', 'name': 'King Abdulaziz', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2936316', 'name': 'Diplomatic Quarters', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2936175', 'name': 'Al Murooj', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2936180', 'name': 'Al Worood', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2936308', 'name': 'Al Rahmaniyah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2936314', 'name': 'Al Sahafa', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2936256', 'name': 'Al Dirah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2936269', 'name': 'Al Yamamah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2936178', 'name': 'Al Farooq', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2936277', 'name': 'Al Yasmeen', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2936229', 'name': 'Ohud', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'k ...
# Completed 14 / 648
# {'data': []}
# Completed 15 / 648
# {'data': []}
# Completed 16 / 648
# {'data': []}
# Completed 17 / 648
# {'data': []}
# Completed 18 / 648
# {'data': []}
# Completed 19 / 648
# {'data': [{'key': '2115663', 'name': 'Az̧ Z̧ahiriyah', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Al-Qassim Province', 'region_id': 3203, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MAZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Al-zahiriyah&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MAZDZD'}}
# Completed 20 / 648
# {'data': [{'key': '2115916', 'name': 'Dammam', 'type': 'city', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True}, {'key': '2896577', 'name': 'Al Rawdah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2896356', 'name': 'Al Adama', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MgZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Ad%20Dammam&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MgZDZD'}}
# Completed 21 / 648
# {'data': []}
# Completed 22 / 648
# {'data': []}
# Completed 23 / 648
# {'data': []}
# Completed 24 / 648
# {'data': []}
# Completed 25 / 648
# {'data': []}
# Completed 26 / 648
# {'data': [{'key': '2116364', 'name': 'Hofuf', 'type': 'city', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MAZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Al%20Hufuf&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MAZDZD'}}
# Completed 27 / 648
# {'data': []}
# Completed 28 / 648
# {'data': []}
# Completed 29 / 648
# {'data': []}
# Completed 30 / 648
# {'data': []}
# Completed 31 / 648
# {'data': []}
# Completed 32 / 648
# {'data': [{'key': '2116956', 'name': 'Mecca', 'type': 'city', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Makkah Region', 'region_id': 3207, 'supports_region': True, 'supports_city': True}, {'key': '2116519', 'name': 'Jeddah', 'type': 'city', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Makkah Region', 'region_id': 3207, 'supports_region': True, 'supports_city': True}, {'key': '2117879', 'name': 'Taif', 'type': 'city', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Makkah Region', 'region_id': 3207, 'supports_region': True, 'supports_city': True}, {'key': '2113851', 'name': 'Ajyad', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Makkah Region', 'region_id': 3207, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2116506', 'name': 'Jarwal', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Makkah Region', 'region_id': 3207, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}, {'key': '2114483', 'name': "Al Khadra'", 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Makkah Region', 'region_id': 3207, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}, {'key': '2917978', 'name': 'King Abdulaziz University', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Makkah Region', 'region_id': 3207, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'NgZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Mecca&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=NgZDZD'}}
# Completed 33 / 648
# {'data': []}
# Completed 34 / 648
# {'data': [{'key': '2114012', 'name': "Al Bakhra'", 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MAZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Al-bakhra&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MAZDZD'}}
# Completed 35 / 648
# {'data': []}
# Completed 36 / 648
# {'data': []}
# Completed 37 / 648
# {'data': []}
# Completed 38 / 648
# {'data': []}
# Completed 39 / 648
# {'data': []}
# Completed 40 / 648
# {'data': []}
# Completed 41 / 648
# {'data': [{'key': '2939670', 'name': 'Al Faisaliyah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Makkah Region', 'region_id': 3207, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2922224', 'name': 'Al Faisaliyah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': "'Asir Region", 'region_id': 4201, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2114085', 'name': 'Al Faisaliyah', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MgZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Al-faisaliyah&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MgZDZD'}}
# Completed 42 / 648
# {'data': [{'key': '2116674', 'name': 'Khobar', 'type': 'city', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True}, {'key': '2896556', 'name': 'Sinaiyat Al Thoqba', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2896546', 'name': 'Al Hamra', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2896407', 'name': 'Al Khozama', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2896444', 'name': 'Al Aqiq', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2896473', 'name': 'Al Bohaira', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2896508', 'name': 'Sinaiyat Al Fawaziah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2896543', 'name': 'Al Amwaj', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2896517', 'name': 'Al Yarmouk', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2896399', 'name': 'Al Raka Al Jenobiah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2896551', 'name': 'Al Shiraa', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2896526', 'name': 'Al Lulu', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2896430', 'name': 'Al Madenah Al Reyadhya', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2896579', 'name': 'Al Akrabiah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarc ...
# Completed 43 / 648
# {'data': []}
# Completed 44 / 648
# {'data': []}
# Completed 45 / 648
# {'data': []}
# Completed 46 / 648
# {'data': []}
# Completed 47 / 648
# {'data': []}
# Completed 48 / 648
# {'data': []}
# Completed 49 / 648
# {'data': []}
# Completed 50 / 648
# {'data': [{'key': '2117290', 'name': 'Qatif', 'type': 'city', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True}, {'key': '2901317', 'name': 'Al Huseen', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2901326', 'name': 'Al Eskan', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2901332', 'name': 'Al Shoekah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2901287', 'name': 'Al Toba', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2901334', 'name': 'Al Wasada', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2901345', 'name': 'Al Bustan', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2901294', 'name': 'Al Thoraiah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2901347', 'name': 'Al Qadeeh', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2901322', 'name': 'Al Jazirah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2901270', 'name': 'Al Madni', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2901276', 'name': 'Al Jarary', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2901330', 'name': 'Al Khowailidiah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2901292', 'name': 'Al Madaras', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hier ...
# Completed 51 / 648
# {'data': [{'key': '2936214', 'name': 'Al Badiah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2896445', 'name': 'Al Badiah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2936384', 'name': 'Dahrat Al Badiah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2113997', 'name': "Al Badi'", 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}, {'key': '2113996', 'name': 'Al Badi`ah', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}, {'key': '2113999', 'name': 'Al Badi`', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Jizan Region', 'region_id': 3210, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}, {'key': '2118254', 'name': 'Z̧ahrat al Badi`ah', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}, {'key': '2114003', 'name': 'Al Badiyi`', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Al Jawf Region', 'region_id': 3212, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}, {'key': '2114001', 'name': 'Al Badiriyah', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Makkah Region', 'region_id': 3207, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'OAZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Al%20Badi&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=OAZDZD'}}
# Completed 52 / 648
# {'data': [{'key': '2114470', 'name': 'Al Kamil', 'type': 'city', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Makkah Region', 'region_id': 3207, 'supports_region': True, 'supports_city': True}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MAZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Al-kamil&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MAZDZD'}}
# Completed 53 / 648
# {'data': []}
# Completed 54 / 648
# {'data': []}
# Completed 55 / 648
# {'data': [{'key': '2115937', 'name': 'Dariyah', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Al-Qassim Province', 'region_id': 3203, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}, {'key': '2936661', 'name': 'Al Diriyah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2113789', 'name': 'Ad Diriyah', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MgZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Dariyah&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MgZDZD'}}
# Completed 56 / 648
# {'data': [{'key': '2113672', 'name': 'Abu `Ashirah', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MAZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Ashirah&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MAZDZD'}}
# Completed 57 / 648
# {'data': [{'key': '2117565', 'name': 'Saihat', 'type': 'city', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True}, {'key': '2904501', 'name': 'Al Ferdaus', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2904499', 'name': 'Al Noor', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2904397', 'name': 'Al Kawthar', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2904500', 'name': 'Al Salam', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2904393', 'name': 'Ghurnatah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2904454', 'name': 'Al Khaleej', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2904433', 'name': 'Al Muntazah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2904466', 'name': 'Al Deerah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2904398', 'name': 'Qurtobah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2904465', 'name': 'Al Khassab', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2904403', 'name': 'Al Gadeer', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2904428', 'name': 'Al Taf', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2904396', 'name': 'Al Naqa', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_nam ...
# Completed 58 / 648
# {'data': []}
# Completed 59 / 648
# {'data': []}
# Completed 60 / 648
# {'data': []}
# Completed 61 / 648
# {'data': [{'key': '2114300', 'name': 'Al Hilwa', 'type': 'city', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MAZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Al-hilwa&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MAZDZD'}}
# Completed 62 / 648
# {'data': [{'key': '2117552', 'name': 'Safwa', 'type': 'city', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MAZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Safwa&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MAZDZD'}}
# Completed 63 / 648
# {'data': []}
# Completed 64 / 648
# {'data': []}
# Completed 65 / 648
# {'data': []}
# Completed 66 / 648
# {'data': []}
# Completed 67 / 648
# {'data': []}
# Completed 68 / 648
# {'data': [{'key': '2117429', 'name': 'Ras Tanura', 'type': 'city', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MAZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Ras%20Tanura&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MAZDZD'}}
# Completed 69 / 648
# {'data': []}
# Completed 70 / 648
# {'data': [{'key': '2116175', 'name': 'Hadban', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Al Jawf Region', 'region_id': 3212, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MAZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Hadban&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MAZDZD'}}
# Completed 71 / 648
# {'data': []}
# Completed 72 / 648
# {'data': []}
# Completed 73 / 648
# {'data': [{'key': '2113659', 'name': 'Abqaiq', 'type': 'city', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MAZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Abqaiq&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MAZDZD'}}
# Completed 74 / 648
# {'data': []}
# Completed 75 / 648
# {'data': []}
# Completed 76 / 648
# {'data': []}
# Completed 77 / 648
# {'data': []}
# Completed 78 / 648
# {'data': []}
# Completed 79 / 648
# {'data': []}
# Completed 80 / 648
# {'data': [{'key': '2115570', 'name': 'Ath Thamiriyah', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Al-Qassim Province', 'region_id': 3203, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MAZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Al-thamiriyah&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MAZDZD'}}
# Completed 81 / 648
# {'data': []}
# Completed 82 / 648
# {'data': [{'key': '2117370', 'name': 'Rabigh', 'type': 'city', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Makkah Region', 'region_id': 3207, 'supports_region': True, 'supports_city': True}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MAZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Rabigh&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MAZDZD'}}
# Completed 83 / 648
# {'data': []}
# Completed 84 / 648
# {'data': []}
# Completed 85 / 648
# {'data': []}
# Completed 86 / 648
# {'data': []}
# Completed 87 / 648
# {'data': [{'key': '2116620', 'name': 'Khafji', 'type': 'city', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True}, {'key': '2116868', 'name': 'Manfadh al Khafji', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MQZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Khafji&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MQZDZD'}}
# Completed 88 / 648
# {'data': []}
# Completed 89 / 648
# {'data': [{'key': '2917822', 'name': 'Al Amariya', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Makkah Region', 'region_id': 3207, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2113895', 'name': 'Al `Amar', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}, {'key': '2113894', 'name': 'Al Amarah', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': "'Asir Region", 'region_id': 4201, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MgZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Al-amar&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MgZDZD'}}
# Completed 90 / 648
# {'data': []}
# Completed 91 / 648
# {'data': [{'key': '2115867', 'name': 'Buraydah', 'type': 'city', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Al-Qassim Province', 'region_id': 3203, 'supports_region': True, 'supports_city': True}, {'key': '2118179', 'name': 'Wahtan', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Al-Qassim Province', 'region_id': 3203, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MQZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Buraydah&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MQZDZD'}}
# Completed 92 / 648
# {'data': [{'key': '2116586', 'name': 'Kabshan', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MAZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Kabshan&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MAZDZD'}}
# Completed 93 / 648
# {'data': []}
# Completed 94 / 648
# {'data': []}
# Completed 95 / 648
# {'data': [{'key': '2116685', 'name': 'Khulais, Makkah', 'type': 'city', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Makkah Region', 'region_id': 3207, 'supports_region': True, 'supports_city': True}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MAZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Khulais&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MAZDZD'}}
# Completed 96 / 648
# {'data': []}
# Completed 97 / 648
# {'data': [{'key': '2117879', 'name': 'Taif', 'type': 'city', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Makkah Region', 'region_id': 3207, 'supports_region': True, 'supports_city': True}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MAZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=At-Ta%20If&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MAZDZD'}}
# Completed 98 / 648
# {'data': []}
# Completed 99 / 648
# {'data': []}
# Completed 100 / 648
# {'data': [{'key': '2114696', 'name': 'Al Mathnah', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Makkah Region', 'region_id': 3207, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MAZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Al-mathnah&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MAZDZD'}}
# Completed 101 / 648
# {'data': []}
# Completed 102 / 648
# {'data': []}
# Completed 103 / 648
# ...
# Completed 592 / 648
# {'data': []}
# Completed 593 / 648
# {'data': []}
# Completed 594 / 648
# {'data': []}
# Completed 595 / 648
# {'data': []}
# Completed 596 / 648
# {'data': []}
# Completed 597 / 648
# {'data': [{'key': '2896566', 'name': 'Al Raka Al Shamaliah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2896399', 'name': 'Al Raka Al Jenobiah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2115246', 'name': 'Ar Rakah', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}, {'key': '2117402', 'name': 'Rakah', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Makkah Region', 'region_id': 3207, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}, {'key': '2117405', 'name': 'Rakk', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': "Ha'il Region", 'region_id': 3206, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}, {'key': '2117404', 'name': 'Raka', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': "'Asir Region", 'region_id': 4201, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}, {'key': '2118098', 'name': 'Umm Rakh', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Tabuk Region', 'region_id': 3211, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}, {'key': '2118051', 'name': 'Umm ar Rakah', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Makkah Region', 'region_id': 3207, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'NwZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Rak&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=NwZDZD'}}
# Completed 598 / 648
# {'data': [{'key': '2114627', 'name': 'Al Madrakah', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Makkah Region', 'region_id': 3207, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MAZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Madrakah&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MAZDZD'}}
# Completed 599 / 648
# {'data': [{'key': '2113769', 'name': 'Al Darb', 'type': 'city', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Jizan Region', 'region_id': 3210, 'supports_region': True, 'supports_city': True}, {'key': '2115929', 'name': 'Darb al Ibl', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Eastern Province', 'region_id': 3202, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MQZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Al-darb&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MQZDZD'}}
# Completed 600 / 648
# {'data': []}
# Completed 601 / 648
# {'data': []}
# Completed 602 / 648
# {'data': [{'key': '2117305', 'name': 'Qiyal', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Al Jawf Region', 'region_id': 3212, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MAZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Qiyal&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MAZDZD'}}
# Completed 603 / 648
# {'data': [{'key': '2117558', 'name': 'Sahla', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MAZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Sahla&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MAZDZD'}}
# Completed 604 / 648
# {'data': []}
# Completed 605 / 648
# {'data': []}
# Completed 606 / 648
# {'data': []}
# Completed 607 / 648
# {'data': []}
# Completed 608 / 648
# {'data': []}
# Completed 609 / 648
# {'data': []}
# Completed 610 / 648
# {'data': []}
# {'data': []}Completed 611 / 648
# Completed 611 / 648
#
# {'data': []}
# Completed 613 / 648
# {'data': []}
# Completed 614 / 648
# {'data': []}
# Completed 615 / 648
# {'data': []}
# Completed 616 / 648
# {'data': []}
# Completed 617 / 648
# {'data': []}
# Completed 618 / 648
# {'data': []}
# Completed 619 / 648
# {'data': []}
# Completed 620 / 648
# {'data': []}
# Completed 621 / 648
# {'data': []}
# Completed 622 / 648
# {'data': []}
# Completed 623 / 648
# {'data': []}
# Completed 624 / 648
# {'data': []}
# Completed 625 / 648
# {'data': [{'key': '2114253', 'name': 'Al Hariq', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MAZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Al-hariq&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MAZDZD'}}
# Completed 626 / 648
# {'data': []}
# Completed 627 / 648
# {'data': []}
# Completed 627 / 648
# {'data': [{'key': '2117603', 'name': 'Sanam', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MAZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Sanam&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MAZDZD'}}
# Completed 628 / 648
# {'data': [{'key': '2116266', 'name': 'Haql', 'type': 'city', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Tabuk Region', 'region_id': 3211, 'supports_region': True, 'supports_city': True}, {'key': '2114244', 'name': 'Al Haql, Al Jawf', 'type': 'city', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Tabuk Region', 'region_id': 3211, 'supports_region': True, 'supports_city': True}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MQZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Haql&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MQZDZD'}}
# Completed 628 / 648
# {'data': []}
# Completed 629 / 648
# {'data': []}
# Completed 630 / 648
# {'data': []}
# Completed 631 / 648
# {'data': []}
# Completed 632 / 648
# {'data': []}
# Completed 633 / 648
# {'data': [{'key': '2113814', 'name': 'Adh Dhibah', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Makkah Region', 'region_id': 3207, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MAZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Dhiba&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MAZDZD'}}
# Completed 634 / 648
# {'data': [{'key': '2922143', 'name': 'Al Khalidiyah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': "'Asir Region", 'region_id': 4201, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2114497', 'name': 'Al Khalidiyah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Riyadh Region', 'region_id': 3205, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}, {'key': '2114498', 'name': 'Al Khalidiyah', 'type': 'neighborhood', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Makkah Region', 'region_id': 3207, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'NEIGHBORHOOD', 'geo_hierarchy_name': 'NEIGHBORHOOD'}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MgZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Al-khalidiyah&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MgZDZD'}}
# Completed 635 / 648
# {'data': []}
# Completed 635 / 648
# {'data': [{'key': '2115525', 'name': 'As Suhaylat', 'type': 'subcity', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Al Madinah Region', 'region_id': 3201, 'supports_region': True, 'supports_city': True, 'geo_hierarchy_level': 'SUBCITY', 'geo_hierarchy_name': 'CITY'}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MAZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Al-suha&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MAZDZD'}}
# Completed 636 / 648
# {'data': []}
# Completed 636 / 648
# {'data': []}
# Completed 637 / 648
# {'data': []}
# Completed 638 / 648
# {'data': []}
# Completed 639 / 648
# {'data': []}
# Completed 640 / 648
# {'data': []}
# Completed 641 / 648
# {'data': []}
# Completed 642 / 648
# {'data': []}
# Completed 643 / 648
# {'data': []}
# Completed 644 / 648
# {'data': []}
# Completed 645 / 648
# {'data': []}
# Completed 646 / 648
# {'data': [{'key': '2116673', 'name': 'Khobara, Al Qasim', 'type': 'city', 'country_code': 'SA', 'country_name': 'Saudi Arabia', 'region': 'Al-Qassim Province', 'region_id': 3203, 'supports_region': True, 'supports_city': True}], 'paging': {'cursors': {'before': 'MAZDZD', 'after': 'MAZDZD'}, 'next': 'https://graph.facebook.com/v21.0/search?access_token=&type=adgeolocation&location_types=%5B%22city%22%5D&q=Al-khobara&country_code=SA&access_token=EAAQqTDw7N4QBAOMb8phRSpBE5h4pSX4h1mwxe1VZAGpZCYMwQdSfhHoT0R8lBqSUqZA8prN8ReZBccwW3XxVcawZAOc2o32NfdcdMFUHXdxIZAW1RqZCaZCVg47xAQdD3mpJZA9TTQJWexgavbTn4zT5w5CwpQrIBXE6Wh6VIjvJ0KGFQbgxZAw8O8&limit=25&after=MAZDZD'}}
# Completed 647 / 648
# {'data': []}
# Completed 648 / 648
# Saved copy as .json file
#          key                                         name          type  \
# 0    2115958                       Dhahran, Ash Sharqiyah          city
# 1    2893100                                    Al Jameah  neighborhood
# 2    2893123                                    Al Taraji  neighborhood
# 3    2893114  King Fahd University of Pet and Min - KFUPM  neighborhood
# 4    2115959                               Dhahran, Jizan          city
# ..       ...                                          ...           ...
# 522  2113814                                   Adh Dhibah       subcity
# 524  2114497                                Al Khalidiyah  neighborhood
# 525  2114498                                Al Khalidiyah  neighborhood
# 526  2115525                                  As Suhaylat       subcity
# 527  2116673                            Khobara, Al Qasim          city
#
#     country_code  country_name              region  region_id  \
# 0             SA  Saudi Arabia    Eastern Province       3202
# 1             SA  Saudi Arabia    Eastern Province       3202
# 2             SA  Saudi Arabia    Eastern Province       3202
# 3             SA  Saudi Arabia    Eastern Province       3202
# 4             SA  Saudi Arabia        'Asir Region       4201
# ..           ...           ...                 ...        ...
# 522           SA  Saudi Arabia       Makkah Region       3207
# 524           SA  Saudi Arabia       Riyadh Region       3205
# 525           SA  Saudi Arabia       Makkah Region       3207
# 526           SA  Saudi Arabia   Al Madinah Region       3201
# 527           SA  Saudi Arabia  Al-Qassim Province       3203
#
#      supports_region  supports_city geo_hierarchy_level geo_hierarchy_name
# 0               True           True                 NaN                NaN
# 1               True           True        NEIGHBORHOOD       NEIGHBORHOOD
# 2               True           True        NEIGHBORHOOD       NEIGHBORHOOD
# 3               True           True        NEIGHBORHOOD       NEIGHBORHOOD
# 4               True           True                 NaN                NaN
# ..               ...            ...                 ...                ...
# 522             True           True             SUBCITY               CITY
# 524             True           True        NEIGHBORHOOD       NEIGHBORHOOD
# 525             True           True        NEIGHBORHOOD       NEIGHBORHOOD
# 526             True           True             SUBCITY               CITY
# 527             True           True                 NaN                NaN
#
# [462 rows x 11 columns]
